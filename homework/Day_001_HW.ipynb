# %% [raw]
# 作業1
#
# 1. 臨床上病患 DNA 序列資料，訓練完成可預測健康人未來可能得到的疾病並提早做預防措施。
# 2. ClinVar，研究人員從醫院蒐集定序資料後自主上傳。
# 3. 結構化表格資料 (.csv)
# 4. 分類

# %% [raw]
# 作業2
# 1. 天氣與載客量關係，並用車流量統計資料預測最快到達時間藉以提升載客量。
# 2. Google trend：比對不同天氣搜尋"載客服務"最多的時間與空間
#    內政資料開放平台：導入歷史車流量資料。
#    氣象局：導入氣象資料
# 3. 結構化資料
# 4. 比較數據分析後載客量與分析前隨機載客量差異

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0 ,100 ,101)
y = (x_lin + np.random.randn(101)*5)*w + b

plt.plot(x_lin, y, 'b.',label = 'data points')
plt.title("Assum we haave data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % MSE)
print("The Mean absolute error is %.3f" % MAE)
# Out:
# The Mean squared error is 7.741
# The Mean absolute error is 2.247
